# %%
# Driveマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ultralyticsインストール
# !pip -q install ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.7 MB/s eta 0:00:00

# %%
# best.pt 読み込み
from ultralytics import YOLO

MODEL_PATH = "/content/drive/MyDrive/jagarico_export/best.pt"

model = YOLO(MODEL_PATH)

print("Model loaded successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Model loaded successfully

# %%
# 推論画像を用意(Driveの画像を使う)
IMAGE_PATH = "/content/drive/MyDrive/test_image.jpg"

# %%
# 推論を実行
results = model.predict(
    source=IMAGE_PATH,
    imgsz=640,
    conf=0.25,
    save=True,
    project="/content/inference_output",
    name="demo"
)

print("Inference complete")
# Out:
# image 1/1 /content/drive/MyDrive/test_image.jpg: 640x480 3 Cheeses, 2 Jaga Butters, 2 Salads, 78.4ms
# Speed: 10.3ms preprocess, 78.4ms inference, 39.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/inference_output/demo
# Inference complete

# %%
# 推論結果を表示
import glob
from IPython.display import Image, display

output_images = glob.glob("/content/inference_output/demo/*")

for img in output_images:
    if img.endswith((".jpg", ".png", ".jpeg")):
        display(Image(filename=img))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
